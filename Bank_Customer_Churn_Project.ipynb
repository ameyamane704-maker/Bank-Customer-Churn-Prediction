# %%
# import pandas to read the csv file
import pandas as pd
df = pd.read_csv("European_Bank.csv")
df.head()
# Out:
#    Year  CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0  2025    15634602  Hargrave          619    France  Female   42       2
# 1  2025    15647311      Hill          608     Spain  Female   41       1
# 2  2025    15619304      Onio          502    France  Female   42       8
# 3  2025    15701354      Boni          699    France  Female   39       1
# 4  2025    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
# to chcek that how many columns and rows are there in the dataset
df.shape
# Out:
# (10000, 14)

# %%
# To check that which columns are there exactly
df.columns
# Out:
# Index(['Year', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender',
#        'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Year               0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#here customer id and surname cannot show that the customer will leave the bank or not so we removed it.
df = df.drop(
    ['CustomerId','Surname'],
    axis=1
)

# %%
#install visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#How many customers stayed
#How many customers left
sns.countplot(x='Exited',data=df),
plt.show()

# %%
#To check the exited members and there age
sns.boxplot(x='Exited',y='Age',data=df),
plt.show()

# %%
df['Year'].value_counts()
# Out:
# Year
# 2025    10000
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Year               0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#Data type of every column
#Number of values
#Missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             10000 non-null  int64
#  1   CreditScore      10000 non-null  int64
#  2   Geography        10000 non-null  object
#  3   Gender           10000 non-null  object
#  4   Age              10000 non-null  int64
#  5   Tenure           10000 non-null  int64
#  6   Balance          10000 non-null  float64
#  7   NumOfProducts    10000 non-null  int64
#  8   HasCrCard        10000 non-null  int64
#  9   IsActiveMember   10000 non-null  int64
#  10  EstimatedSalary  10000 non-null  float64
#  11  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
# To check Do males and females churn differently
sns.countplot(x='Gender',hue='Exited',data=df),
plt.show()

# %%
sns.countplot(x='Geography',hue='Exited',data=df),
plt.show()

# %%
# Which age groups leave the bank more
plt.figure(figsize=(10,5))
sns.histplot(
    data=df,
    x='Age',
    hue='Exited',
    kde='True')
plt.show()

# %%
# To check whether customers with higher balances churn more
sns.boxplot(
    x='Exited',
    y='Balance',
    data=df,
)
plt.show()

# %%
df.isnull().sum()
# Out:
# Year               0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             10000 non-null  int64
#  1   CreditScore      10000 non-null  int64
#  2   Geography        10000 non-null  object
#  3   Gender           10000 non-null  object
#  4   Age              10000 non-null  int64
#  5   Tenure           10000 non-null  int64
#  6   Balance          10000 non-null  float64
#  7   NumOfProducts    10000 non-null  int64
#  8   HasCrCard        10000 non-null  int64
#  9   IsActiveMember   10000 non-null  int64
#  10  EstimatedSalary  10000 non-null  float64
#  11  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
# To check that owning more products reduce churn
sns.countplot(x='NumOfProducts',hue='Exited',data=df),
plt.show()

# %%
sns.countplot(
    x='IsActiveMember',
    hue='Exited',
    data=df
)

plt.show()

# %%
sns.countplot(
    x='HasCrCard',
    hue='Exited',
    data=df
)

plt.show()

# %%
plt.figure(figsize=(10,8))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap='coolwarm'
)

plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                  Year  CreditScore       Age    Tenure   Balance  \
# Year              NaN          NaN       NaN       NaN       NaN
# CreditScore       NaN     1.000000 -0.003965  0.000842  0.006268
# Age               NaN    -0.003965  1.000000 -0.009997  0.028308
# Tenure            NaN     0.000842 -0.009997  1.000000 -0.012254
# Balance           NaN     0.006268  0.028308 -0.012254  1.000000
# NumOfProducts     NaN     0.012238 -0.030680  0.013444 -0.304180
# HasCrCard         NaN    -0.005458 -0.011721  0.022583 -0.014858
# IsActiveMember    NaN     0.025651  0.085472 -0.028362 -0.010084
# EstimatedSalary   NaN    -0.001384 -0.007201  0.007784  0.012797
# Exited            NaN    -0.027094  0.285323 -0.014001  0.118533
#
#                  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# Year                       NaN        NaN             NaN              NaN
# CreditScore           0.012238  -0.005458        0.025651        -0.001384
# ...

# %%
df=df.drop('Year',axis=1)

# %%
# Balance relative to salary
df['BalanceSalaryRatio'] = (
    df['Balance'] /
    (df['EstimatedSalary'] + 1)
)

# Age and loyalty interaction
df['AgeTenure'] = (
    df['Age'] *
    df['Tenure']
)

# Customer engagement score
df['EngagementScore'] = (
    df['IsActiveMember'] +
    df['HasCrCard']
)

# Products per year with bank
df['ProductDensity'] = (
    df['NumOfProducts'] /
    (df['Tenure'] + 1)
)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  BalanceSalaryRatio  \
# 0          1               1        101348.88       1            0.000000
# 1          0               1        112542.58       0            0.744670
# 2          1               0        113931.57       1            1.401362
# 3          0               0         93826.63       0            0.000000
# 4          1               1         79084.10       0            1.587035
#
#    AgeTenure  EngagementScore  ProductDensity
# ...

# %%
df[['BalanceSalaryRatio',
    'AgeTenure',
    'EngagementScore',
    'ProductDensity']].describe()
# Out:
#        BalanceSalaryRatio     AgeTenure  EngagementScore  ProductDensity
# count        10000.000000  10000.000000     10000.000000    10000.000000
# mean             3.790150    194.804000         1.220600        0.367173
# std            100.055758    127.939996         0.672444        0.337760
# min              0.000000      0.000000         0.000000        0.090909
# 25%              0.000000     90.000000         1.000000        0.166667
# 50%              0.746998    180.000000         1.000000        0.250000
# 75%              1.514002    280.000000         2.000000        0.500000
# max           9770.883148    880.000000         2.000000        3.000000

# %%
if 'Geography' in df.columns and 'Gender' in df.columns:
    df=pd.get_dummies(
        df,
        columns=['Geography','Gender'],
        drop_first=True
    )
    print("Columns 'Geography' and 'Gender' processed into dummy variables.")
else:
    print("Columns 'Geography' and 'Gender' already processed or not found.")
# Out:
# Columns 'Geography' and 'Gender' processed into dummy variables.

# %%
x = df.drop('Exited',axis=1)
y = df['Exited']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(
    max_iter=1000
)

lr.fit(
    X_train_scaled,
    y_train
)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = lr.predict(
    X_test_scaled
)

# %%
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

print(
    "Accuracy:",
    accuracy_score(
        y_test,
        y_pred
    )
)

print(
    classification_report(
        y_test,
        y_pred
    )
)

print(
    confusion_matrix(
        y_test,
        y_pred
    )
)
# Out:
# Accuracy: 0.809
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89      1593
#            1       0.60      0.19      0.28       407
#
#     accuracy                           0.81      2000
#    macro avg       0.71      0.58      0.59      2000
# weighted avg       0.78      0.81      0.77      2000
#
# [[1542   51]
#  [ 331   76]]

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

rf.fit(
    X_train,
    y_train
)

y_pred_rf = rf.predict(
    X_test
)

# %%
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

print(
    "Accuracy:",
    accuracy_score(
        y_test,
        y_pred_rf
    )
)

print(
    classification_report(
        y_test,
        y_pred_rf
    )
)

print(
    confusion_matrix(
        y_test,
        y_pred_rf
    )
)
# Out:
# Accuracy: 0.865
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      1593
#            1       0.78      0.47      0.58       407
#
#     accuracy                           0.86      2000
#    macro avg       0.83      0.72      0.75      2000
# weighted avg       0.86      0.86      0.85      2000
#
# [[1540   53]
#  [ 217  190]]

# %%
import pandas as pd

importance = pd.DataFrame({
    'Feature': x.columns,
    'Importance': rf.feature_importances_
})

importance = importance.sort_values(
    by='Importance',
    ascending=False
)

print(
    importance.head(10)
)
# Out:
#                Feature  Importance
# 1                  Age    0.193485
# 4        NumOfProducts    0.107956
# 0          CreditScore    0.103891
# 7      EstimatedSalary    0.103048
# 9            AgeTenure    0.096727
# 3              Balance    0.094898
# 8   BalanceSalaryRatio    0.082017
# 11      ProductDensity    0.055995
# 2               Tenure    0.040579
# 6       IsActiveMember    0.028568

# %%
importance = pd.DataFrame({
    'Feature': x.columns,
    'Importance': rf.feature_importances_
})

importance = importance.sort_values(
    by='Importance',
    ascending=False
)

importance.head(15)
# Out:
#                Feature  Importance
# 1                  Age    0.193485
# 4        NumOfProducts    0.107956
# 0          CreditScore    0.103891
# 7      EstimatedSalary    0.103048
# 9            AgeTenure    0.096727
# 3              Balance    0.094898
# 8   BalanceSalaryRatio    0.082017
# 11      ProductDensity    0.055995
# 2               Tenure    0.040579
# 6       IsActiveMember    0.028568
# 12   Geography_Germany    0.025941
# 10     EngagementScore    0.023105
# 14         Gender_Male    0.018525
# 13     Geography_Spain    0.013653
# 5            HasCrCard    0.011612

# %%
df['ChurnRiskScore'] = rf.predict_proba(x)[:,1] * 100

df[['ChurnRiskScore']].head()
# Out:
#    ChurnRiskScore
# 0            64.5
# 1            12.0
# 2            98.0
# 3             0.5
# 4             7.0

# %%
df['RiskCategory'] = pd.cut(
    df['ChurnRiskScore'],
    bins=[0,40,70,100],
    labels=['Low Risk','Medium Risk','High Risk']
)

df['RiskCategory'].value_counts()
# Out:
# RiskCategory
# Low Risk       7224
# High Risk      1422
# Medium Risk     546
# Name: count, dtype: int64
